# %% [markdown]
# # ESTIMATION AND CONFIDENCE INTERVALS

# %% [markdown]
# ### Data
#
# ###### A total of 15 print-heads were randomly selected and tested until failure. The durability of eachprint-head (in millions of characters) was recorded as follows:1.13, 1.55, 1.43, 0.92, 1.25, 1.36, 1.32, 0.85, 1.07, 1.48, 1.20, 1.33, 1.18, 1.22, 1.29

# %% [markdown]
# ## Assignment Tasks

# %% [markdown]
# ### a. Build 99% Confidence Interval Using Sample Standard Deviation
#
# ###### Assuming the sample is representative of the population, construct a 99% confidence interval for the mean number of characters printed before the print-head fails using the sample standard deviation. Explain the steps you take and the rationale behind using the t-distribution for this task.

# %%
import scipy.stats as stats
import numpy as np
import pandas as pd

# %%
## given data
n=15
data=np.array([1.13, 1.55, 1.43, 0.92, 1.25, 1.36, 1.32, 0.85, 1.07, 1.48, 1.20, 1.33, 1.18, 1.22, 1.29])
## CI=0.99,alpha=0.01

# %%
# mean and standard deviation
x_bar=data.mean().round(2)
s=data.std(ddof=1).round(2)
print(x_bar)
print(s)

# %%
t_critical=stats.t.ppf(0.995,14)
t_critical

# %%
# margin of error
margin_of_error=t_critical*(s/np.sqrt(n))
margin_of_error

# %%
pop_mean_lower=x_bar-margin_of_error
pop_mean_lower

# %%
pop_mean_upper=x_bar+margin_of_error
pop_mean_upper

# %% [raw]
# To construct the 99% confidence interval for the mean durability of print-heads, the sample mean and standard deviation were first calculated from the given data. Since the confidence level is 99%, the level of significance (alpha) is 1%, and with a sample size of 15, the degrees of freedom are 14. Using the t-distribution, the critical value corresponding to 99% confidence and 14 degrees of freedom was obtained. The margin of error was then computed using the formula t_critical*(s/sqrt(n)). Based on these calculations, the 99% confidence interval for the population mean is (1.0902, 1.3871). This indicates that we are 99% confident the true mean durability of all print-heads lies between 1.0902 and 1.3871 million characters. The t-distribution was used because the sample size is small (n < 30) and the population standard deviation is unknown.

# %% [markdown]
# ### b. Build 99% Confidence Interval Using Known Population Standard Deviation
#
# ###### If it were known that the population standard deviation is 0.2 million characters, construct a 99%confidence interval for the mean number of characters printed before failure.

# %%
## given data
n=15
x_bar=1.24
pop_stddev=0.2
s=0.19
# CI=0.99 , alpha=0.01

# %%
z_critical=stats.norm.ppf(0.995)
z_critical

# %%
margin_error=z_critical*(pop_stddev/np.sqrt(n))
margin_error

# %%
pop_mean_lower=x_bar-margin_error
pop_mean_lower

# %%
pop_mean_upper=x_bar+margin_error
pop_mean_upper

# %% [raw]
# Eventhough the number of sample is 15, which is less than 30, the z_critical value is used because the population standard deviation is known. Using the calculation of the lower condidence limit (x_bar-z_critical*(pop_stddev/np.sqrt(n))) and the upper condidence limit (x_bar+z_critical*(pop_stddev/np.sqrt(n))), the 99% confidence interval for the population mean is found to lie between ((1.106,1.374)million characters.
